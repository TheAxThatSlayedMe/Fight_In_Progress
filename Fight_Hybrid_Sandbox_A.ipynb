# %%
import random
import itertools
import functools
import operator

import random
from functools import reduce

# %%
#Function to fetch the fighter txt files associated with player_name

#Function to fetch the contest txt files associated with player_name

#function to turn those txt files into lists

#function to choose random from the lists to build fighters, contests



def get_combatant():
    links = get_from_file('data/links')
    combatants_list = []

    for link in links:
        filename = get_filename(link)
        if not path.exists(filename):
            combatants = combatants_from_links(link)
            combatants_list.append(combatants)
            cache_combatants(filename, combatants)

    if combatants_list:
        return combatants_list
    else:
        return combatants_from_files()


def combatants_from_files():
combatants_list = []
for file in glob.glob('data/*.txt'):
    combatants_list.append(get_from_file(file))

return combatants_list


if __name__ == "__main__":

    player_name = input("Who is playing?")

# %%
def offer_list_choice():
    print(#function that lists directory of all lists)
    select_lists = input(int("Which of these " + a_lists + " lists would you like to play with?"))

# %%
def sign_in():
    player_name = input(str('Who is playing? Enter your username or "guest.": '))
    return player_name
    
if __name__ == "__main__":

    player_name = sign_in()
    print(player_name)
# Out:
# lj

# %%
# Bunch of functions, some of which I deleted from main

# Sets player_name to whatever the user types.
def sign_in():
    player_name = input(str('Who is playing? Enter your username or "guest.": '))
    yield player_name #Henceforth, sign_in() will retain this value, because it was yield. sign_in() == whatever name the player inputed. player_name is global.

# Creates a directory for all a player's packs
def create_a_directory():
    dir_name = player_name
    #Code that creates a directory named whatever value player_name has.

#Adds files to a specified directory
def add_to_directory(dir_name_or_path):
    #Code that adds txt files generated by other functions to the player's directory,
    #OR to the main directory or wherever

# Gathers together all txts associated with a user into a list
def collect_txts(txts_being_worked_with, txt_generating_functions(), txts_list_variable ):
    txts_being_worked_with = [txt_generating_functions(), txts_list_variable]
    return txts_being_worked_with

# Lists the index of a directory
def list_directory(dir_pointer):
    #list index of dir_pointer, dir_pointer being replaced by player_name or main_directory or whatever

#generates txt files from a txt file of links to the specified directory
def txt_gen_fun_from_links(dir_pointer):

#generates txt files from manually updated variables, or from a function that lets up update variables
def txt_gen_fun_from_variables(var_list, dir_pointer):
    #take all items from var_list and put them into dir_pointer; replace var_list and dir_pointer with global variables to use.

# Gets items from a specified file or directory path, turns into a bunch of strings?
def get_from_file(filename):
    with open(filename) as f:
        return [x.strip() for x in f.readlines()]

# Appends items from get_from_file(whatever file) to combatants_list, returns that as a list
def combatants_from_files():
    combatants_list = []
    for file in glob.glob('data/*.txt'): #watch out for how I make this universal
        combatants_list.append(get_from_file(file))

    return combatants_list

#Might need to add EJ's function get_combatant() here. get_combatant is what he sets fighters = at start of 
# execution, but I think it can just be combatants_from_files() for now. 

# Turns all items in a txt file into a list. 
def turn_txt_file_into_list(specified_txt_file):

def merge_lists(a_list):
    #append output from turn_txt_file_into_list(), variables for hand-modified lists, etc. into a mega list.
    a_list = []

# This is how fighters and contests get their values at the beginning of the executed code.
def set_variables_to_strings_from_lists(a_list):


# Combines packs (fighers or contest)
def combine_packs(a_list)


def random_ages(min_age=1, max_age=101):
    while True:
        yield random.randint(min_age, max_age) 

# random_choice() replaces random_fighters() and random_contests()
#Replace a_list with contests or fighters to update these global values to a random item from their lists.
def random_choice(a_list): #Well then why do I need a different function here?
    while True:
        yield random.choice(a_list)

def get_fight(fighter_a, fighter_a_age, fighter_b, fighter_b_age, contest):
    return reduce(concat, [ 

        'Who would win in ',
        contest,
        ', a ',
        str(fighter_a_age),
        '-year-old ',
        fighter_a,
        ' or a ',
        str(fighter_b_age),
        '-year-old ',
        fighter_b,
        '?'
    ])

# Gets crap from a file, returns as a bunch of strings?
def get_from_file(filename):
    with open(filename) as f:
        return [x.strip() for x in f.readlines()]


def get_combatant():
    links = get_from_file('data/links')
    combatants_list = []

    for link in links:
        filename = get_filename(link)
        if not path.exists(filename):
            combatants = combatants_from_links(link)
            combatants_list.append(combatants)
            cache_combatants(filename, combatants)

    if combatants_list:
        return combatants_list
    else:
        return combatants_from_files()

# %%
numbers1 = [1,2,3]
numbers2 = [4,5,6]

result = map(lambda x, y: x+y, numbers1, numbers2)

print(list(result))
# Out:
# [5, 7, 9]

# %%
list1 = ['Superman', 'Batman', 'Spiderman']
list2 = ['bear', 'cat', 'shark']

result = map(function, numbers1, numbers2)

print(list(result))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-719ecaa6fb9f> in <module>
#       2 list2 = ['bear', 'cat', 'shark']
#       3
# ----> 4 result = map(result.append, numbers1, numbers1)
#       5
#       6 print(list(result))
#
# AttributeError: 'map' object has no attribute 'append'

# %%
all_packs = ['./a.txt', './b.txt', './c.txt']

result = map(txt_items_to_list, all_packs)

def txt_items_to_list(filename):
    variable = open(filename, 'r').read().splitlines()

# %%
# Out:
# ['./a.txt', './b.txt', './c.txt']

# %%
#works

variable = open('a.txt', 'r').read().splitlines() 
print(variable)
# Out:
# ['apple', 'android', 'Amy']

# %%
#works

def txt_items_to_list(filename):
    variable = open(filename, 'r').read().splitlines()
    print(variable)

txt_items_to_list('./b.txt')
# Out:
# ['bear', 'bee', 'Bob']

# %%
#works: prints ['./a.txt', './b.txt', './c.txt'] three times

list_of_packs = ['./a.txt', './b.txt', './c.txt']


def provide_next_pack_from_list(list_of_packs):
    while True:
        yield next(list_of_packs)

def add_a_bunch_of_packs():
    for i in (list_of_packs):
        whatever = provide_next_pack_from_list(list_of_packs)
        print(list_of_packs)

add_a_bunch_of_packs()
# Out:
# ['./a.txt', './b.txt', './c.txt']
# ['./a.txt', './b.txt', './c.txt']
# ['./a.txt', './b.txt', './c.txt']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a3c0d14e97e9> in <module>
#      13         print(list_of_packs)
#      14
# ---> 15 add_a_bunch_of_packs(list_of_packs)
#
# <ipython-input-6-a3c0d14e97e9> in add_a_bunch_of_packs(list_of_packs)
#      10 def add_a_bunch_of_packs(list_of_packs):
#      11     for i in (list_of_packs):
# ---> 12         whatever = open(list_of_packs, 'r').read().splitlines()
#      13         print(list_of_packs)
#      14
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
#This prints a list of 3 "generator objects."

list_of_packs = ['./a.txt', './b.txt', './c.txt']


def provide_next_pack_from_list(list_of_packs):
    while True:
        yield next(list_of_packs)

def add_a_bunch_of_packs():
    for i in (list_of_packs):
        whatever = provide_next_pack_from_list(list_of_packs)
        print(whatever)

add_a_bunch_of_packs()
# Out:
# <generator object provide_next_pack_from_list at 0x00000214559E9660>
# <generator object provide_next_pack_from_list at 0x00000214559E97C8>
# <generator object provide_next_pack_from_list at 0x00000214559E9390>

# %%
#silently produces one genterator object add_a_bunch_of_packs

list_of_packs = ['./a.txt', './b.txt', './c.txt']


def provide_next_pack_from_list(list_of_packs):
    while True:
        yield next(list_of_packs)

def add_a_bunch_of_packs():
    for i in (list_of_packs):
        whatever = open(list_of_packs, 'r').read().splitlines()
        yield whatever

add_a_bunch_of_packs()
# Out:
# <generator object add_a_bunch_of_packs at 0x00000214559E95E8>

# %%
list_of_packs = ['./a.txt', './b.txt', './c.txt']


def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print(list)

turn_list_into_iterable(list_of_packs)
    



def provide_next_pack_from_list(list_of_packs):
    while True:
        yield next(list_of_packs)

def add_a_bunch_of_packs():
    for i in (list_of_packs):
        whatever = open(list_of_packs, 'r').read().splitlines()
        yield whatever

add_a_bunch_of_packs()

def idk():
    map(function to which map passes each element of given iterable, given iterable)
    map()

# %%
#prints list_of_packs. But is it iterable now?

list_of_packs = ['./a.txt', './b.txt', './c.txt']


def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print(list)

turn_list_into_iterable(list_of_packs)
# Out:
# ['./a.txt', './b.txt', './c.txt']

# %%
#prints list of items from one txt file.

def txt_items_to_list(filename):
    variable = open(filename, 'r').read().splitlines()
    print(variable)

txt_items_to_list('./b.txt')
# Out:
# ['bear', 'bee', 'Bob']

# %%
#prints txt_items_to_list(just_one) as the contents of the txt file in just_one

list_of_packs = ['./a.txt', './b.txt', './c.txt']
just_one = './b.txt'

def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print(list)

turn_list_into_iterable(list_of_packs)

def txt_items_to_list(filename):
    one_pack_list = open(filename, 'r').read().splitlines()
    print(one_pack_list)

txt_items_to_list(just_one)
# Out:
# ['./a.txt', './b.txt', './c.txt']
# ['bear', 'bee', 'Bob']

# %%
list_of_packs = ['./a.txt', './b.txt', './c.txt']
just_one = './a.txt'
iterable_list = iter(list_of_packs)


def turn_list_into_iterable(list):
    iterable_list = iter(list)
    yield iterable_list

def txt_items_to_list(filename):
    one_pack_list = open(filename, 'r').read().splitlines()
    print(one_pack_list)

def all_packs_to_one_list(iterable_function): #(like turn_list_into_iterable())
    all_packs_list = iterable_function
    print(all_packs_list) # that's one generator object
    map(txt_items_to_list(iterable_list), turn_list_into_iterable(list))



print(list(turn_list_into_iterable(list_of_packs)))
#all_packs_to_one_list(turn_list_into_iterable(list))

# %%
list_of_packs = ['./a.txt', './b.txt', './c.txt']
just_one = './a.txt'
iterable_list = iter(list_of_packs)

# %%
# prints 
#output B
#['apple', 'android', 'Amy']
#output B
#['bear', 'bee', 'Bob']
#output B
#['cat', 'carrot', 'civet']

list_of_packs = ['./a.txt', './b.txt', './c.txt']
#just_one = './b.txt'

def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print('output A')
    print(iterable_list) #this prints a list_iterator object
    yield iterable_list #Whatever I put in for "list" is now iterable

#turn_list_into_iterable(list_of_packs)

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)

#txt_items_to_list(just_one)
#this yields a list made from the *txt file defined by just_one, or by filename


for filename in list_of_packs:
    txt_items_to_list(filename)

#map(func, *iterables)

#for i in iterable_list:
    #something = next(iterable_list)
    #txt_items_to_list(something)




#def generate_ints():
    #for i in range(0,5):
        #yield i
# Out:
# output B
# ['apple', 'android', 'Amy']
# output B
# ['bear', 'bee', 'Bob']
# output B
# ['cat', 'carrot', 'civet']

# %%
# prints 
#output B
#['apple', 'android', 'Amy']
#output B
#['bear', 'bee', 'Bob']
#output B
#['cat', 'carrot', 'civet']

list_of_packs = ['./a.txt', './b.txt', './c.txt']

def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print('output A')
    print(iterable_list) #this prints a list_iterator object
    yield iterable_list #Whatever I put in for "list" is now iterable

#turn_list_into_iterable(list_of_packs)

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)

def merge_pack_lists():
    for filename in list_of_packs:
        txt_items_to_list(filename)
        #all_lists = map(append_list_to_lists(), iterable_list)

txt_items_to_list(merge_pack_lists())
# Out:
# output B
# ['apple', 'android', 'Amy']
# output B
# ['bear', 'bee', 'Bob']
# output B
# ['cat', 'carrot', 'civet']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-00ab456a21f7> in <module>
#      27         #all_lists = map(append_list_to_lists(), iterable_list)
#      28
# ---> 29 txt_items_to_list(merge_pack_lists())
#
# <ipython-input-71-00ab456a21f7> in txt_items_to_list(filename)
#      18
#      19 def txt_items_to_list(filename): #where do I get filename?
# ---> 20     one_pack_list = open(filename, 'r').read().splitlines()
#      21     print('output B')
#      22     print(one_pack_list)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
# prints 
#output B
#['apple', 'android', 'Amy']
#output B
#['bear', 'bee', 'Bob']
#output B
#['cat', 'carrot', 'civet']

list_of_packs = ['./a.txt', './b.txt', './c.txt']

def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print('output A')
    print(iterable_list) #this prints a list_iterator object
    yield iterable_list #Whatever I put in for "list" is now iterable

#turn_list_into_iterable(list_of_packs)

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)

def merge_pack_lists():
    for filename in list_of_packs:
        txt_items_to_list(filename)
        #all_lists = map(append_list_to_lists(), iterable_list)

merge_pack_lists()
# Out:
# output B
# ['apple', 'android', 'Amy']
# output B
# ['bear', 'bee', 'Bob']
# output B
# ['cat', 'carrot', 'civet']

# %%
list_of_packs = ['./a.txt', './b.txt', './c.txt']

def turn_list_into_iterable(list):
    iterable_list = iter(list)
    print('output A')
    print(iterable_list) #this prints a list_iterator object
    yield iterable_list #Whatever I put in for "list" is now iterable

#turn_list_into_iterable(list_of_packs)

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)
    yield one_pack_list

def list_of_lists():
    for filename in list_of_packs:
        something = ['uh']
        #txt_items_to_list(filename)
        something.append(txt_items_to_list(filename))
        print("output D")
        print(something)
        #all_lists = map(append_list_to_lists(), iterable_list)

def merge_pack_lists():
    whatever = map(list_of_lists(), list_of_packs)
    print("output C")
    print(whatever) # i get one map object


merge_pack_lists()
# Out:
# output D
# ['uh', <generator object txt_items_to_list at 0x0000021455AD1750>]
# output D
# ['uh', <generator object txt_items_to_list at 0x0000021455AD1750>]
# output D
# ['uh', <generator object txt_items_to_list at 0x0000021455AD1750>]
# output C
# ...

# %%
list_of_packs = ['./a.txt', './b.txt', './c.txt']


def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)

def something(variable, list_generating_function())):
    return variable.append(list_generating_function())
# Out:
#   File "<ipython-input-93-0945cabad814>", line 9
#     def something(variable, list_generating_function()):
#                                                     ^
# SyntaxError: invalid syntax

# %%
user_list_of_packs = iter(['./a.txt', './b.txt', './c.txt'])

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)

def list_pack_lists(chosen_list_of_packs):
    for filename in chosen_list_of_packs:
        txt_items_to_list(filename)
        #all_lists = map(append_list_to_lists(), iterable_list)

list_pack_lists(user_list_of_packs)
# Out:
# output B
# ['apple', 'android', 'Amy']
# output B
# ['bear', 'bee', 'Bob']
# output B
# ['cat', 'carrot', 'civet']

# %%
user_list_of_packs = iter(['./a.txt', './b.txt', './c.txt'])
filename = ''

def txt_items_to_list(filename, chosen_list_of_packs): #where do I get filename?
    for filename in chosen_list_of_packs:
        txt_items_to_list(filename, chosen_list_of_packs)
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)

def list_pack_lists(chosen_list_of_packs):
    for filename in chosen_list_of_packs:
        txt_items_to_list(filename, chosen_list_of_packs)
        #all_lists = map(append_list_to_lists(), iterable_list)

txt_items_to_list(filename, user_list_of_packs)
# Out:
# output B
# ['cat', 'carrot', 'civet']
# output B
# ['cat', 'carrot', 'civet']
# output B
# ['bear', 'bee', 'Bob']
# output B
# ['apple', 'android', 'Amy']

# %%
user_list_of_packs = iter(['./a.txt', './b.txt', './c.txt'])

def txt_items_to_list(filename): #where do I get filename?
    something = []
    one_pack_list = open(filename, 'r').read().splitlines()
    print('output B')
    print(one_pack_list)
    yield something.append(one_pack_list)
    print(something)


def list_pack_lists(chosen_list_of_packs):
    for filename in chosen_list_of_packs:
        txt_items_to_list(filename)

list_pack_lists(user_list_of_packs)

# %%
user_list_of_packs = ['./a.txt', './b.txt', './c.txt']

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    step = one_pack_list
    print('output B')
    print(step)

def list_pack_lists(chosen_list_of_packs):
    for whatever_filename in chosen_list_of_packs:
        txt_items_to_list(whatever_filename) #whatever_filename fills in filename
        #all_lists = map(append_list_to_lists(), iterable_list)
        


 

list_pack_lists(user_list_of_packs)
# Out:
# output B
# ['apple', 'android', 'Amy']
# output B
# ['bear', 'bee', 'Bob']
# output B
# ['cat', 'carrot', 'civet']

# %%
lla = ['a', 'aa', 'aaa']
llb = ['b', 'bb', 'bbb']

def combine_lists():
    big_list = []
    big_list.append(lla)
    print(big_list)
    big_list.append(llb)
    print(big_list)

combine_lists()
# Out:
# [['a', 'aa', 'aaa']]
# [['a', 'aa', 'aaa'], ['b', 'bb', 'bbb']]

# %%
#prints a list of lists.

lla = ['a', 'aa', 'aaa']
llb = ['b', 'bb', 'bbb']

def combine_lists():
    big_list = []
    for i in range(0,1):
        big_list.append(lla)
        big_list.append(llb)
        print(big_list)


combine_lists()
# Out:
# [['a', 'aa', 'aaa'], ['b', 'bb', 'bbb']]

# %%
# makes a single list from the stuff in other lists!!!!


from functools import reduce
from operator import concat


lla = ['a', 'aa', 'aaa']
llb = ['b', 'bb', 'bbb']

def combine_lists2():
    return reduce(concat, [
        lla,
        llb


    ])


combine_lists2()
# Out:
# ['a', 'aa', 'aaa', 'b', 'bb', 'bbb']

# %%
#Makes a list from only the first pack.

from functools import reduce
from operator import concat

user_list_of_packs = ['./a.txt', './b.txt', './c.txt']

def txt_items_to_list(filename): #where do I get filename?
    one_pack_list = open(filename, 'r').read().splitlines()
    step = one_pack_list
    print('output B')
    print(step)
    return(step)

def list_pack_lists(chosen_list_of_packs):
    for whatever_filename in chosen_list_of_packs:
        return txt_items_to_list(whatever_filename) #whatever_filename fills in filename
        #all_lists = map(append_list_to_lists(), iterable_list)
        

def combine_lists2():
    return reduce(concat, [
        'here it is: ',
        str(list_pack_lists(user_list_of_packs)),
        str(list_pack_lists(user_list_of_packs))

        


    ])


combine_lists2()
# Out:
# output B
# ['apple', 'android', 'Amy']
# output B
# ['apple', 'android', 'Amy']
# "here it is: ['apple', 'android', 'Amy']['apple', 'android', 'Amy']"

# %%
from functools import reduce
from operator import concat


lla = ['a', 'aa', 'aaa']
llb = ['b', 'bb', 'bbb'] 
llc = []
#These need to be replaced by the funtion that finds all txt files in the directory. And creates a variable for each one.

def all_packs(llc):
    llc = [lla, llb]
    return

def combine_lists2():
    return reduce(concat, [
        all_packs(llc)


    ])


combine_lists2()

# %%
#WORKS! Creates a generator object, but with list() prints list of all lists & items.a
#NOTE that when random operates on this output, it's looking at a list of lists, so
#the first number will look at the index of an entire list, and the second number will be the
#index of an item inside that list.
#NOTE also that combine_lists2() is the variable that will be called. It doesn't need to have anything inside its () because it's just grabbing another function-- list_of_packs(local)-- to run within itself. 

from functools import reduce
from operator import concat


def list_of_packs(): #This function must be rewritten to look in directory and create variables assigned to each list
    lla = ['a', 'aa', 'aaa']
    llb = ['b', 'bb', 'bbb']
    yield lla
    yield llb #return only returns ONE of these, just llb

def combine_lists2():
    return reduce(concat, [
        list_of_packs()


    ])


combine_lists2()
print(list((combine_lists2())))
# Out:
# [['a', 'aa', 'aaa'], ['b', 'bb', 'bbb']]

# %%
#WORKS!!! Flattens a list of lists.

nested_list = [['a', 'aa', 'aaa'], ['b', 'bb', 'bbb']]

flat_list = []
for sublist in nested_list:
    for item in sublist:
        flat_list.append(item)
print(flat_list)
# Out:
# ['a', 'aa', 'aaa', 'b', 'bb', 'bbb']

# %%
#WORKS!! nested_list comes from another function. May need to 
#add something to convert generator object to list.

nested_list = [['a', 'aa', 'aaa'], ['b', 'bb', 'bbb']]

def flatten_list(local_nested_list):

    flat_list = []
    for sublist in local_nested_list:
        for item in sublist:
            flat_list.append(item)
    yield flat_list

print(flat_list)
print(flatten_list(nested_list))
print(list(flatten_list(nested_list)))
# Out:
# ['a', 'aa', 'aaa', 'b', 'bb', 'bbb']
# <generator object flatten_list at 0x0000021F87CF9D68>
# [['a', 'aa', 'aaa', 'b', 'bb', 'bbb']]

# %%
def flatten_list(local_nested_list):

    flat_list = []
    for sublist in local_nested_list:
        for item in sublist:
            flat_list.append(item)
    return list(flat_list)
    yield list(flat_list)

flatten_list(nested_list)
# Out:
# <generator object flatten_list at 0x0000021F87D64C78>

# %%
#WORKS: combine the functions to create list

#print(flatten_list(combine_lists2()))
#print(list(flatten_list(combine_lists2())))
#print(list(flatten_list(nested_list)))

#The function I probably want, maybe have to add list(): 
list(flatten_list(combine_lists2()))

#So, to put it together in the next cell:
# Out:
# [['a', 'aa', 'aaa', 'b', 'bb', 'bbb']]

# %%
#WORKS! What was created above. This will be in Step 7

opponents = []

def gather_list_functions(list_name): #will be gather_list_functions(opponents) or (contests)
    list_name = list(flatten_list(combine_lists2()))
    return list_name

gather_list_functions(opponents)
# Out:
# []

# %%
# pull a random item from gather_list_functions(opponents)

def random_item(a_list):
    while True:
        yield random.choice(a_list)

random_item(gather_list_functions(opponents))
# Out:
# <generator object random_item at 0x0000021F87D64A20>

# %%
from functools import reduce
from operator import concat
import random
from random import randint

#This section creates a flat list of lists, but it's assigned to the function and not to a global variable.

def list_of_packs(): #This function must be rewritten to look in directory and create variables assigned to each list
    lla = ['a', 'aa', 'aaa']
    llb = ['b', 'bb', 'bbb']
    yield lla
    yield llb #return only returns ONE of these, just llb

#
def combine_lists2():
    return reduce(concat, [
        list_of_packs()

    ])

def flatten_list(local_nested_list):

    flat_list = []
    for sublist in local_nested_list:
        for item in sublist:
            flat_list.append(item)
    yield flat_list

#def gather_list_functions(list_name): #will be gather_list_functions(opponents) or (contests)
    #global return_list_name
    #list_name = list(flatten_list(combine_lists2()))
    #return_list_name = list_name
    #return return_list_name #yield list_name creates a generator object\

def gather_list_functions(list_name): #will be gather_list_functions(opponents) or (contests)
    list_name = list(flatten_list(combine_lists2()))
    yield list_name #yield list_name creates a generator object

opponents = []

gather_list_functions(opponents)
# Out:
# <generator object gather_list_functions at 0x0000021F87D649A8>

# %%
whatever = ["wheat", "corn", "apple"]

def random_item(a_list):
    while True:
        yield random.choice(a_list)

print(random_item(whatever))

# %%
import random

numberList = [111,222,333,444,555]
print("random item from list is: ", random.choice(numberList))
# Out:
# random item from list is:  444

# %%
5+3

# %%
import random
from functools import reduce
from operator import concat

#This section creates a flat list of lists, but it's assigned to the function and not to a global variable.

def list_of_packs(): #This function must be rewritten to look in directory and create variables assigned to each list
    lla = ['a', 'aa', 'aaa']
    llb = ['b', 'bb', 'bbb']
    yield lla
    yield llb #return only returns ONE of these, just llb

#
def combine_lists2():
    return reduce(concat, [
        list_of_packs()

    ])

def flatten_list(local_nested_list):

    flat_list = []
    for sublist in local_nested_list:
        for item in sublist:
            flat_list.append(item)
    yield flat_list 

def gather_list_functions(list_name): #will be gather_list_functions(opponents) or (contests)
    list_name = list(flatten_list(combine_lists2())) #This creates a list of a single list
    list_name = list_name[0] #This removes the extra brackets by defining it as just the first index
    return list_name #yield list_name creates a generator object

opponents = []

gather_list_functions(opponents)
# Out:
# ['a', 'aa', 'aaa', 'b', 'bb', 'bbb']

# %%
#This works, but the problem is that the list it's choosing from is in two sets of list brackets. 

#print(random.choice(gather_list_functions(opponents))) #A

print(random.choice(opponents))

# %%
def random_item(a_list):
    while True:
        return random.choice(a_list)

random_item(opponents)

# %%
#WORKS! Sets the global variable user

def get_user():
    global user
    user = input("What is your username?")
    return

get_user()
print(user)
# Out:
# lj

# %%
#This doesn't work because a variable can't be both local and global

def get_user(local):
    global local
    local = input("What is your username?")
    return
user = ""
get_user(user)
print(user)
# Out:
#   File "<ipython-input-12-491cf31d58a8>", line 5
#     user = ""
#
# ^
# SyntaxError: name 'local' is parameter and global

# %%
def get_user_packs():
    open('./fighters.txt', 'r').read().splitlines()
# Out:
# 6

# %%
from bs4 import BeautifulSoup
import glob
import random
import requests
from os import path

def combatants_from_files():
    combatants_list = []
    for file in ('abc/opponents/*.txt'):
        combatants_list.append(get_from_file(file))

    return combatants_list

combatants_from_files()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-da7474bdee88> in <module>
#      12     return combatants_list
#      13
# ---> 14 combatants_from_files()
#
# <ipython-input-19-da7474bdee88> in combatants_from_files()
#       8     combatants_list = []
#       9     for file in ('abc/opponents/*.txt'):
# ---> 10         combatants_list.append(get_from_file(file))
#      11
#      12     return combatants_list
#
# NameError: name 'get_from_file' is not defined

# %%
8+2
# Out:
# 10

# %%
from bs4 import BeautifulSoup
import glob
import random
import requests
from os import path

contests = open('./abc/contests/z.txt', 'r').read().splitlines()
print(contests)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-315d48ffd9f2> in <module>
#       5 from os import path
#       6
# ----> 7 contests = open('./abc/contests/z.txt', 'r').read().splitlines()
#       8 print(contests)
#
# FileNotFoundError: [Errno 2] No such file or directory: './abc/contests/z.txt'

# %%
contests = open('./contests.txt', 'r').read().splitlines()

# %%
from bs4 import BeautifulSoup
import glob
import random
import requests
from os import path

def get_from_file(filename):
    with open(filename) as f:
        return [x.strip() for x in f.readlines()]

def get_combatant():
    links = get_from_file('abc/opponents/a.txt')
    combatants_list = []

    for link in links:
        filename = get_filename(link)
        if not path.exists(filename):
            combatants = combatants_from_links(link)
            combatants_list.append(combatants)
            cache_combatants(filename, combatants)

    if combatants_list:
        return combatants_list
    else:
        return combatants_from_files()

get_combatant()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-e17887182483> in <module>
#      25         return combatants_from_files()
#      26
# ---> 27 get_combatant()
#
# <ipython-input-24-e17887182483> in get_combatant()
#      10
#      11 def get_combatant():
# ---> 12     links = get_from_file('abc/opponents/a.txt')
#      13     combatants_list = []
#      14
#
# <ipython-input-24-e17887182483> in get_from_file(filename)
#       6
#       7 def get_from_file(filename):
# ----> 8     with open(filename) as f:
#       9         return [x.strip() for x in f.readlines()]
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc/opponents/a.txt'

# %%
path = 'packs/b.txt'
text = open(path)
print(text.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-17adcc134b3b> in <module>
#       1 path = 'packs/b.txt'
# ----> 2 text = open(path)
#       3 print(text.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'packs/b.txt'
